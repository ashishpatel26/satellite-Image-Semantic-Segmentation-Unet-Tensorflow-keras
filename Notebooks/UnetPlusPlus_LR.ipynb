# %%
import os
# !pip install unrar
# !unrar x '/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/800_dataset_with_semantic_segmentation.rar'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use("ggplot")
# %matplotlib inline
import gc

from tqdm.notebook import trange, tqdm

from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Dropout, concatenate, UpSampling2D
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras import backend as K

  
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.callbacks import *

import random 

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %%
w, h = 304,304
border = 5

# %%
ids = next(os.walk("/content/800_dataset_with_semantic_segmentation/train_images/"))[2] # list of names all images in the given path
print("No. of images = ", len(ids))
# Out:
# No. of images =  61

# %% [markdown]
# # **Data Reading and Train test split**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import glob
train = sorted(glob.glob("/content/800_dataset_with_semantic_segmentation/train_images/*"))
train_mask = sorted(glob.glob("/content/800_dataset_with_semantic_segmentation/train_segmentation/*.png"))[:64]
print(f'Total Train Images : {len(train)}\nTotal Mask Image : {len(train_mask)}')
# Out:
# Total Train Images : 61
# Total Mask Image : 61

# %%
X = np.zeros((len(train), h, w, 3), dtype=np.float32)
y = np.zeros((len(train_mask), h, w, 1), dtype=np.float32)

# %%
for n, (img, mimg) in tqdm(enumerate(zip(train, train_mask))):
  # print(n, img, mimg)
  # Load images
  img = load_img(img)
  x_img = img_to_array(img)
  x_img = resize(x_img, (h, w, 3), mode = 'constant', preserve_range = True)
  # # Load masks
  mask = img_to_array(load_img(mimg, color_mode = "grayscale"))
  mask = resize(mask, (h, w, 1), mode = 'constant', preserve_range = True)
  # # Save images
  X[n] = x_img/255.0
  y[n] = mask/255.0
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
# Save the files in Numpy array for reusability
# np.save('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/X.npy', X)
# np.save('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/y.npy', y)
# print(X.shape, y.shape)
X = np.load('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/X.npy')
y = np.load('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/y.npy')
print(X.shape, y.shape)
# Out:
# (61, 304, 304, 3) (61, 304, 304, 1)

# %%
# Split train and valid
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
gc.collect()
# Out:
# (54, 304, 304, 3) (54, 304, 304, 1) (7, 304, 304, 3) (7, 304, 304, 1)
# 21

# %% [markdown]
# # **Visualization the image and It masks**

# %%
# plt.colormaps()

# %%
# Visualize any randome image along with the mask
ix = random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0 # salt indicator

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 15))

ax1.imshow(X_train[ix, ..., 0], cmap="seismic", interpolation = 'bilinear')
if has_mask: # if salt
    # draw a boundary(contour) in the original image separating salt and non-salt areas
    ax1.contour(y_train[ix].squeeze(), colors = 'k', linewidths = 5, levels = [0.5])
ax1.set_title('Satellight Image')
ax1.set_axis_off()
ax2.imshow(y_train[ix].squeeze(), cmap = 'gist_gray', interpolation = 'bilinear')
ax2.set_title('Mask Satellight Image')
ax2.set_axis_off()

# %%
dropout_rate = 0.5

def conv_batchnorm_relu_block(input_tensor, nb_filter, kernel_size=3):

    x = Conv2D(nb_filter, (kernel_size, kernel_size), padding='same')(input_tensor)
    x = BatchNormalization(axis=2)(x)
    x = Activation('relu')(x)

    return x


def UnetPP(input_shape, n_labels, using_deep_supervision=False):

    nb_filter = [32,64,128,256,512]

    # Set image data format to channels first
    global bn_axis

    K.set_image_data_format("channels_last")
    bn_axis = -1
    inputs = Input(shape=input_shape, name='input_image')

    conv1_1 = conv_batchnorm_relu_block(inputs, nb_filter=nb_filter[0])
    pool1 = AvgPool2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = conv_batchnorm_relu_block(pool1, nb_filter=nb_filter[1])
    pool2 = AvgPool2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=bn_axis)
    conv1_2 = conv_batchnorm_relu_block(conv1_2,  nb_filter=nb_filter[0])

    conv3_1 = conv_batchnorm_relu_block(pool2, nb_filter=nb_filter[2])
    pool3 = AvgPool2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=bn_axis)
    conv2_2 = conv_batchnorm_relu_block(conv2_2, nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=bn_axis)
    conv1_3 = conv_batchnorm_relu_block(conv1_3, nb_filter=nb_filter[0])

    conv4_1 = conv_batchnorm_relu_block(pool3, nb_filter=nb_filter[3])
    pool4 = AvgPool2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=bn_axis)
    conv3_2 = conv_batchnorm_relu_block(conv3_2, nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=bn_axis)
    conv2_3 = conv_batchnorm_relu_block(conv2_3, nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=bn_axis)
    conv1_4 = conv_batchnorm_relu_block(conv1_4, nb_filter=nb_filter[0])

    conv5_1 = conv_batchnorm_relu_block(pool4, nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = conv_batchnorm_relu_block(conv4_2, nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=bn_axis)
    conv3_3 = conv_batchnorm_relu_block(conv3_3, nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=bn_axis)
    conv2_4 = conv_batchnorm_relu_block(conv2_4, nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=bn_axis)
    conv1_5 = conv_batchnorm_relu_block(conv1_5, nb_filter=nb_filter[0])

    nestnet_output_1 = Conv2D(n_labels, (1, 1), activation='sigmoid', name='output_1',padding='same')(conv1_2)
    nestnet_output_2 = Conv2D(n_labels, (1, 1), activation='sigmoid', name='output_2', padding='same' )(conv1_3)
    nestnet_output_3 = Conv2D(n_labels, (1, 1), activation='sigmoid', name='output_3', padding='same')(conv1_4)
    nestnet_output_4 = Conv2D(n_labels, (1, 1), activation='sigmoid', name='output_4', padding='same')(conv1_5)

    if using_deep_supervision:
        model = Model(input=inputs, output=[nestnet_output_1,
                                            nestnet_output_2,
                                            nestnet_output_3,
                                            nestnet_output_4])
    else:
        model = Model(inputs=inputs, outputs=nestnet_output_4)

    return model

# %%
from keras import backend as K
K.clear_session()

# input_img = Input((h, w, 3), name='img')
# del model
model = UnetPP(input_shape = (304, 304,3), n_labels=1)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5)]
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)
gc.collect()
# Out:
# 95693

# %%
# del model
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 304, 304, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 304, 304, 32) 896         input_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 304, 304, 32) 1216        conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 304, 304, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# pool1 (AveragePooling2D)        (None, 152, 152, 32) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 152, 152, 64) 18496       pool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 152, 152, 64) 608         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 152, 152, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# pool2 (AveragePooling2D)        (None, 76, 76, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 76, 76, 128)  73856       pool2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 76, 76, 128)  304         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 76, 76, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# pool3 (AveragePooling2D)        (None, 38, 38, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 38, 38, 256)  295168      pool3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 38, 38, 256)  152         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 38, 38, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# pool4 (AveragePooling2D)        (None, 19, 19, 256)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 19, 19, 512)  1180160     pool4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 19, 19, 512)  76          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 19, 19, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 38, 38, 256)  524544      activation_10[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 38, 38, 512)  0           up42[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 76, 76, 128)  131200      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 38, 38, 256)  1179904     merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 76, 76, 256)  0           up32[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 152, 152, 64) 32832       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 38, 38, 256)  152         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 76, 76, 128)  295040      merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 152, 152, 128 0           up22[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 304, 304, 32) 8224        activation_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 38, 38, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 76, 76, 128)  304         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 152, 152, 64) 73792       merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 304, 304, 64) 0           up12[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 76, 76, 128)  131200      activation_11[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 76, 76, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 152, 152, 64) 608         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 304, 304, 32) 18464       merge12[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 76, 76, 384)  0           up33[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 152, 152, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 152, 152, 64) 32832       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 304, 304, 32) 1216        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 76, 76, 128)  442496      merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 152, 152, 192 0           up23[0][0]
#                                                                  activation_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 304, 304, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 304, 304, 32) 8224        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 76, 76, 128)  304         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 152, 152, 64) 110656      merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 304, 304, 96) 0           up13[0][0]
#                                                                  activation[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 76, 76, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 152, 152, 64) 608         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 304, 304, 32) 27680       merge13[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 152, 152, 64) 32832       activation_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 152, 152, 64) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 304, 304, 32) 1216        conv2d_5[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 152, 152, 256 0           up24[0][0]
#                                                                  activation_1[0][0]
#                                                                  activation_4[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 304, 304, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 304, 304, 32) 8224        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 152, 152, 64) 147520      merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 304, 304, 128 0           up14[0][0]
#                                                                  activation[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 152, 152, 64) 608         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 304, 304, 32) 36896       merge14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 152, 152, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 304, 304, 32) 1216        conv2d_9[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 304, 304, 32) 8224        activation_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 304, 304, 32) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 304, 304, 160 0           up15[0][0]
#                                                                  activation[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_5[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 304, 304, 32) 46112       merge15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 304, 304, 32) 1216        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 304, 304, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 304, 304, 1)  33          activation_14[0][0]
# ==================================================================================================
# Total params: 4,875,309
# Trainable params: 4,870,407
# Non-trainable params: 4,902
# __________________________________________________________________________________________________

# %%
def lr_scheduler(epoch, lr):
    decay_rate = 0.1
    decay_step = 10
    if epoch % decay_step == 0 and epoch:
        return lr * decay_rate
    return lr

callbacks = [
    # EarlyStopping(patience=10, verbose=1),
    # CyclicLR(base_lr=0.0001, max_lr=0.000001, mode='triangular', step_size= 8 * (X_train.shape[0] // 6)),
    # ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    LearningRateScheduler(lr_scheduler, verbose=1),
    ModelCheckpoint('model-UnetPP.h5', verbose=1, save_best_only=True, save_weights_only=True),
    CSVLogger("dataUnetPP.csv"),
    TensorBoard(log_dir='./logs')
]

# %%
results = model.fit(X_train, y_train, batch_size=6, epochs=5, callbacks=callbacks, validation_data=(X_test, y_test), use_multiprocessing=True)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.8124999264255166e-05.
# Epoch 1/5
# 9/9 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9655 - auc: 0.6967 - sensitivity_at_specificity: 0.7218 - specificity_at_sensitivity: 0.7369
# Epoch 00001: val_loss improved from inf to 0.31696, saving model to model-UnetPP.h5
# 9/9 [==============================] - 6s 715ms/step - loss: 0.0433 - accuracy: 0.9655 - auc: 0.6967 - sensitivity_at_specificity: 0.7218 - specificity_at_sensitivity: 0.7369 - val_loss: 0.3170 - val_accuracy: 0.9784 - val_auc: 0.7093 - val_sensitivity_at_specificity: 0.8187 - val_specificity_at_sensitivity: 0.7317
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 3.8124999264255166e-05.
# Epoch 2/5
# 9/9 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9655 - auc: 0.7049 - sensitivity_at_specificity: 0.6433 - specificity_at_sensitivity: 0.6629
# Epoch 00002: val_loss improved from 0.31696 to 0.29105, saving model to model-UnetPP.h5
# 9/9 [==============================] - 6s 684ms/step - loss: 0.0417 - accuracy: 0.9655 - auc: 0.7049 - sensitivity_at_specificity: 0.6433 - specificity_at_sensitivity: 0.6629 - val_loss: 0.2910 - val_accuracy: 0.9784 - val_auc: 0.7093 - val_sensitivity_at_specificity: 0.8268 - val_specificity_at_sensitivity: 0.7270
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 3.8124999264255166e-05.
# Epoch 3/5
# 9/9 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9655 - auc: 0.6982 - sensitivity_at_specificity: 0.7809 - specificity_at_sensitivity: 0.7232
# Epoch 00003: val_loss improved from 0.29105 to 0.26604, saving model to model-UnetPP.h5
# 9/9 [==============================] - 6s 687ms/step - loss: 0.0404 - accuracy: 0.9655 - auc: 0.6982 - sensitivity_at_specificity: 0.7809 - specificity_at_sensitivity: 0.7232 - val_loss: 0.2660 - val_accuracy: 0.9784 - val_auc: 0.7131 - val_sensitivity_at_specificity: 0.8438 - val_specificity_at_sensitivity: 0.7219
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 3.8124999264255166e-05.
# Epoch 4/5
# 9/9 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9655 - auc: 0.7082 - sensitivity_at_specificity: 0.7367 - specificity_at_sensitivity: 0.6037
# Epoch 00004: val_loss improved from 0.26604 to 0.24198, saving model to model-UnetPP.h5
# 9/9 [==============================] - 6s 687ms/step - loss: 0.0391 - accuracy: 0.9655 - auc: 0.7082 - sensitivity_at_specificity: 0.7367 - specificity_at_sensitivity: 0.6037 - val_loss: 0.2420 - val_accuracy: 0.9784 - val_auc: 0.7181 - val_sensitivity_at_specificity: 0.8635 - val_specificity_at_sensitivity: 0.7152
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 3.8124999264255166e-05.
# Epoch 5/5
# 9/9 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9655 - auc: 0.7083 - sensitivity_at_specificity: 0.6711 - specificity_at_sensitivity: 0.6538
# Epoch 00005: val_loss improved from 0.24198 to 0.21941, saving model to model-UnetPP.h5
# 9/9 [==============================] - 6s 687ms/step - loss: 0.0381 - accuracy: 0.9655 - auc: 0.7083 - sensitivity_at_specificity: 0.6711 - specificity_at_sensitivity: 0.6538 - val_loss: 0.2194 - val_accuracy: 0.9784 - val_auc: 0.7215 - val_sensitivity_at_specificity: 0.8316 - val_specificity_at_sensitivity: 0.7574

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#        loss  accuracy  ...  val_specificity_at_sensitivity        lr
# 4  0.038144  0.965463  ...                        0.757436  0.000038
# 3  0.039095  0.965463  ...                        0.715199  0.000038
# 2  0.040379  0.965463  ...                        0.721941  0.000038
# 1  0.041686  0.965463  ...                        0.726970  0.000038
# 0  0.043346  0.965463  ...                        0.731702  0.000038
#
# [5 rows x 11 columns]

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %% [markdown]
# # **Inference**

# %%
model.load_weights('model-UnetPP.h5')

# %%
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2194 - accuracy: 0.9784 - auc: 0.7215 - sensitivity_at_specificity: 0.8316 - specificity_at_sensitivity: 0.7574
# [0.21940870583057404,
#  0.9783973693847656,
#  0.7215108871459961,
#  0.8316279053688049,
#  0.7574355602264404]

# %%
# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_test, verbose=1)
# Out:
# 2/2 [==============================] - 3s 1s/step
# 1/1 [==============================] - 0s 155ms/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    """Function to plot the results"""
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Satellight Image')
    ax[0].set_axis_off()

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Satellight Mask Image')
    ax[1].set_axis_off()

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Satelight Image Predicted')
    ax[2].set_axis_off()
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Satellight Mask Image Predicted binary');
    ax[3].set_axis_off()

# %% [markdown]
# # **Predictions on training set**

# %%
# Check if training data looks all right
plot_sample(X_train, y_train, preds_train, preds_train_t, ix=14)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)
