# %%
import os
# !pip install unrar
# !unrar x '/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/800_dataset_with_semantic_segmentation.rar'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use("ggplot")
# %matplotlib inline
import gc

from tqdm.notebook import trange, tqdm

from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Dropout, concatenate, UpSampling2D
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras import backend as K

  
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.callbacks import *

import random 

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %%
w, h = 304,304
border = 5

# %%
ids = next(os.walk("/content/800_dataset_with_semantic_segmentation/train_images/"))[2] # list of names all images in the given path
print("No. of images = ", len(ids))
# Out:
# No. of images =  61

# %% [markdown]
# # **Data Reading and Train test split**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import glob
train = sorted(glob.glob("/content/800_dataset_with_semantic_segmentation/train_images/*"))
train_mask = sorted(glob.glob("/content/800_dataset_with_semantic_segmentation/train_segmentation/*.png"))[:64]
print(f'Total Train Images : {len(train)}\nTotal Mask Image : {len(train_mask)}')
# Out:
# Total Train Images : 61
# Total Mask Image : 61

# %%
X = np.zeros((len(train), h, w, 3), dtype=np.float32)
y = np.zeros((len(train_mask), h, w, 1), dtype=np.float32)

# %%
for n, (img, mimg) in tqdm(enumerate(zip(train, train_mask))):
  # print(n, img, mimg)
  # Load images
  img = load_img(img)
  x_img = img_to_array(img)
  x_img = resize(x_img, (h, w, 3), mode = 'constant', preserve_range = True)
  # # Load masks
  mask = img_to_array(load_img(mimg, color_mode = "grayscale"))
  mask = resize(mask, (h, w, 1), mode = 'constant', preserve_range = True)
  # # Save images
  X[n] = x_img/255.0
  y[n] = mask/255.0
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
print(X.shape, y.shape)
# Out:
# (61, 304, 304, 3) (61, 304, 304, 1)

# %%
# Split train and valid
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
gc.collect()
# Out:
# (54, 304, 304, 3) (54, 304, 304, 1) (7, 304, 304, 3) (7, 304, 304, 1)
# 8

# %% [markdown]
# # **Visualization the image and It masks**

# %%
# Visualize any randome image along with the mask
ix = random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0 # salt indicator

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 15))

ax1.imshow(X_train[ix, ..., 0], interpolation = 'bilinear')
if has_mask: # if salt
    # draw a boundary(contour) in the original image separating salt and non-salt areas
    ax1.contour(y_train[ix].squeeze(), colors = 'k', linewidths = 5, levels = [0.5])
ax1.set_title('Satellight Image')
ax1.set_axis_off()
ax2.imshow(y_train[ix].squeeze(), cmap = 'gray', interpolation = 'bilinear')
ax2.set_title('Mask Satellight Image')
ax2.set_axis_off()

# %%
def VGGUnet(image_size, vgg_weight_path=None):
    inputs = Input((image_size, image_size, 3))
    # Block 1
    x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)
    x = BatchNormalization()(x)
    block_1_out = Activation('relu')(x)

    x = MaxPooling2D()(block_1_out)

    # Block 2
    x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)
    x = BatchNormalization()(x)
    block_2_out = Activation('relu')(x)

    x = MaxPooling2D()(block_2_out)

    # Block 3
    x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv3')(x)
    x = BatchNormalization()(x)
    block_3_out = Activation('relu')(x)

    x = MaxPooling2D()(block_3_out)

    # Block 4
    x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv3')(x)
    x = BatchNormalization()(x)
    block_4_out = Activation('relu')(x)

    x = MaxPooling2D()(block_4_out)

    # Block 5
    x = Conv2D(512, (3, 3), padding='same', name='block5_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv3')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    for_pretrained_weight = MaxPooling2D()(x)

    # Load pretrained weights.
    if vgg_weight_path is not None:
        vgg16 = Model(inputs, for_pretrained_weight)
        vgg16.load_weights(vgg_weight_path, by_name=True)

    # UP 1
    x = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_4_out])
    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 2
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_3_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 3
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_2_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 4
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_1_out])
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(1, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)

    outputs = Activation('sigmoid')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
from keras import backend as K
K.clear_session()

# input_img = Input((h, w, 3), name='img')
# del model
model = VGGUnet(image_size = 304)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5)]
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)
gc.collect()
# Out:
# 18894

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 304, 304, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 304, 304, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 304, 304, 64) 256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 304, 304, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 304, 304, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 304, 304, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 304, 304, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 152, 152, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 152, 152, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 152, 152, 128 512         block2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 152, 152, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 152, 152, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 152, 152, 128 512         block2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 152, 152, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 76, 76, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 76, 76, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 76, 76, 256)  1024        block3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 76, 76, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 76, 76, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 76, 76, 256)  1024        block3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 76, 76, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 76, 76, 256)  590080      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 76, 76, 256)  1024        block3_conv3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 76, 76, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 38, 38, 256)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 38, 38, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 38, 38, 512)  2048        block4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 38, 38, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 38, 38, 512)  2359808     activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 38, 38, 512)  2048        block4_conv2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 38, 38, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 38, 38, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 38, 38, 512)  2048        block4_conv3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 38, 38, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 19, 19, 512)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 19, 19, 512)  2359808     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 19, 19, 512)  2048        block5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 19, 19, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 19, 19, 512)  2359808     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 19, 19, 512)  2048        block5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 19, 19, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 19, 19, 512)  2359808     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 19, 19, 512)  2048        block5_conv3[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 19, 19, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 38, 38, 512)  1049088     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 38, 38, 512)  2048        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 38, 38, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38, 38, 1024) 0           activation_13[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 38, 38, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 38, 38, 512)  2048        conv2d[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 38, 38, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 38, 38, 512)  2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 38, 38, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 38, 38, 512)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 76, 76, 256)  524544      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 76, 76, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 76, 76, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 76, 76, 512)  0           activation_16[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 76, 76, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 76, 76, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 76, 76, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 76, 76, 256)  590080      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 76, 76, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 76, 76, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 152, 152, 128 131200      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 152, 152, 128 512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 152, 152, 128 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 152, 152, 256 0           activation_19[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 152, 152, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 152, 152, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 152, 152, 128 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 152, 152, 128 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 152, 152, 128 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 152, 152, 128 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 304, 304, 64) 32832       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 304, 304, 64) 256         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 304, 304, 64) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 304, 304, 128 0           activation_22[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 304, 304, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 304, 304, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 304, 304, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 304, 304, 64) 36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 304, 304, 64) 256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 304, 304, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 304, 304, 1)  577         activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 304, 304, 1)  4           conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 304, 304, 1)  0           batch_normalization_25[0][0]
# ==================================================================================================
# Total params: 25,883,589
# Trainable params: 25,869,379
# Non-trainable params: 14,210
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-VggUnet.h5', verbose=1, save_best_only=True, save_weights_only=True),
    CSVLogger("dataResUnet.csv"),
    TensorBoard(log_dir='./logs')
]

# %%
results = model.fit(X_train, y_train, batch_size=6, epochs=5, callbacks=callbacks, validation_data=(X_test, y_test), use_multiprocessing=True)
# Out:
# Epoch 1/5
# 9/9 [==============================] - ETA: 0s - loss: 0.7113 - accuracy: 0.8444 - auc: 0.7686 - sensitivity_at_specificity: 0.8062 - specificity_at_sensitivity: 0.8558
# Epoch 00001: val_loss improved from inf to 280233.93750, saving model to model-VggUnet.h5
# 9/9 [==============================] - 3s 382ms/step - loss: 0.7113 - accuracy: 0.8444 - auc: 0.7686 - sensitivity_at_specificity: 0.8062 - specificity_at_sensitivity: 0.8558 - val_loss: 280233.9375 - val_accuracy: 0.3641 - val_auc: 0.4994 - val_sensitivity_at_specificity: 0.0000e+00 - val_specificity_at_sensitivity: 0.3722
# Epoch 2/5
# 9/9 [==============================] - ETA: 0s - loss: 0.6964 - accuracy: 0.8282 - auc: 0.7713 - sensitivity_at_specificity: 0.7867 - specificity_at_sensitivity: 0.8768
# Epoch 00002: val_loss improved from 280233.93750 to 38861.64453, saving model to model-VggUnet.h5
# 9/9 [==============================] - 3s 362ms/step - loss: 0.6964 - accuracy: 0.8282 - auc: 0.7713 - sensitivity_at_specificity: 0.7867 - specificity_at_sensitivity: 0.8768 - val_loss: 38861.6445 - val_accuracy: 0.1286 - val_auc: 0.5007 - val_sensitivity_at_specificity: 0.0000e+00 - val_specificity_at_sensitivity: 0.1315
# Epoch 3/5
# 9/9 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.8185 - auc: 0.8160 - sensitivity_at_specificity: 0.8353 - specificity_at_sensitivity: 0.8940
# Epoch 00003: val_loss improved from 38861.64453 to 1598.16309, saving model to model-VggUnet.h5
# 9/9 [==============================] - 3s 368ms/step - loss: 0.6867 - accuracy: 0.8185 - auc: 0.8160 - sensitivity_at_specificity: 0.8353 - specificity_at_sensitivity: 0.8940 - val_loss: 1598.1631 - val_accuracy: 0.0385 - val_auc: 0.4891 - val_sensitivity_at_specificity: 0.0000e+00 - val_specificity_at_sensitivity: 0.0786
# Epoch 4/5
# 9/9 [==============================] - ETA: 0s - loss: 0.6803 - accuracy: 0.8682 - auc: 0.7940 - sensitivity_at_specificity: 0.7869 - specificity_at_sensitivity: 0.9152
# Epoch 00004: val_loss improved from 1598.16309 to 6.27563, saving model to model-VggUnet.h5
# 9/9 [==============================] - 3s 371ms/step - loss: 0.6803 - accuracy: 0.8682 - auc: 0.7940 - sensitivity_at_specificity: 0.7869 - specificity_at_sensitivity: 0.9152 - val_loss: 6.2756 - val_accuracy: 0.4516 - val_auc: 0.4984 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.5013
# Epoch 5/5
# 9/9 [==============================] - ETA: 0s - loss: 0.6784 - accuracy: 0.8705 - auc: 0.8006 - sensitivity_at_specificity: 0.8052 - specificity_at_sensitivity: 0.9122
# Epoch 00005: val_loss did not improve from 6.27563
# 9/9 [==============================] - 3s 327ms/step - loss: 0.6784 - accuracy: 0.8705 - auc: 0.8006 - sensitivity_at_specificity: 0.8052 - specificity_at_sensitivity: 0.9122 - val_loss: 6044.1611 - val_accuracy: 0.7298 - val_auc: 0.4984 - val_sensitivity_at_specificity: 0.2569 - val_specificity_at_sensitivity: 0.0000e+00

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#        loss  accuracy  ...  val_specificity_at_sensitivity     lr
# 3  0.680298  0.868194  ...                        0.501345  0.001
# 2  0.686662  0.818537  ...                        0.078633  0.001
# 4  0.678356  0.870500  ...                        0.000000  0.001
# 1  0.696377  0.828158  ...                        0.131539  0.001
# 0  0.711317  0.844375  ...                        0.372217  0.001
#
# [5 rows x 11 columns]

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %% [markdown]
# # **Inference**

# %%
model.load_weights('model-VggUnet.h5')

# %%
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2756 - accuracy: 0.4516 - auc: 0.4984 - sensitivity_at_specificity: 0.5000 - specificity_at_sensitivity: 0.5013
# [6.275632381439209,
#  0.45160701870918274,
#  0.4984031617641449,
#  0.5000357627868652,
#  0.5013453364372253]

# %%
# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_test, verbose=1)
# Out:
# 2/2 [==============================] - 2s 919ms/step
# 1/1 [==============================] - 0s 111ms/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    """Function to plot the results"""
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Satellight Image')
    ax[0].set_axis_off()

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Satellight Mask Image')
    ax[1].set_axis_off()

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Satelight Image Predicted')
    ax[2].set_axis_off()
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Satellight Mask Image Predicted binary');
    ax[3].set_axis_off()

# %% [markdown]
# # **Predictions on training set**

# %%
# Check if training data looks all right
plot_sample(X_train, y_train, preds_train, preds_train_t, ix=14)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)
