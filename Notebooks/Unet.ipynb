# %%
import os
# !pip install unrar
# !unrar x '/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/800_dataset_with_semantic_segmentation.rar'

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use("ggplot")
# %matplotlib inline
import gc

from tqdm.notebook import trange, tqdm

from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Dropout, concatenate, UpSampling2D
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras import backend as K

  
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.callbacks import *

import random 

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %%
w, h = 304,304
border = 5

# %%
ids = next(os.walk("/content/800_dataset_with_semantic_segmentation/train_images/"))[2] # list of names all images in the given path
print("No. of images = ", len(ids))
# Out:
# No. of images =  61

# %% [markdown]
# # **Data Reading and Train test split**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import glob
train = sorted(glob.glob("/content/800_dataset_with_semantic_segmentation/train_images/*"))
train_mask = sorted(glob.glob("/content/800_dataset_with_semantic_segmentation/train_segmentation/*.png"))[:64]
print(f'Total Train Images : {len(train)}\nTotal Mask Image : {len(train_mask)}')
# Out:
# Total Train Images : 61
# Total Mask Image : 61

# %%
X = np.zeros((len(train), h, w, 3), dtype=np.float32)
y = np.zeros((len(train_mask), h, w, 1), dtype=np.float32)

# %%
for n, (img, mimg) in tqdm(enumerate(zip(train, train_mask))):
  # print(n, img, mimg)
  # Load images
  img = load_img(img)
  x_img = img_to_array(img)
  x_img = resize(x_img, (h, w, 3), mode = 'constant', preserve_range = True)
  # # Load masks
  mask = img_to_array(load_img(mimg, color_mode = "grayscale"))
  mask = resize(mask, (h, w, 1), mode = 'constant', preserve_range = True)
  # # Save images
  X[n] = x_img/255.0
  y[n] = mask/255.0
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
# Save the files in Numpy array for reusability
np.save('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/X.npy', X)
np.save('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/y.npy', y)
# print(X.shape, y.shape)
X = np.load('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/X.npy')
y = np.load('/content/drive/MyDrive/Fatepura_satellite_dataset_800_altitude/XandY/y.npy')
print(X.shape, y.shape)
# Out:
# (61, 304, 304, 3) (61, 304, 304, 1)

# %%
# Split train and valid
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
gc.collect()
# Out:
# (54, 304, 304, 3) (54, 304, 304, 1) (7, 304, 304, 3) (7, 304, 304, 1)
# 20

# %% [markdown]
# # **Visualization the image and It masks**

# %%
# Visualize any randome image along with the mask
ix = random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0 # salt indicator

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 15))

ax1.imshow(X_train[ix, ..., 0], interpolation = 'bilinear')
if has_mask: # if salt
    # draw a boundary(contour) in the original image separating salt and non-salt areas
    ax1.contour(y_train[ix].squeeze(), colors = 'k', linewidths = 5, levels = [0.5])
ax1.set_title('Satellight Image')
ax1.set_axis_off()
ax2.imshow(y_train[ix].squeeze(), cmap = 'gray', interpolation = 'bilinear')
ax2.set_title('Mask Satellight Image')
ax2.set_axis_off()

# %%
# dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(32)
# valset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(32)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def Unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
from keras import backend as K
K.clear_session()

input_img = Input((h, w, 3), name='img')
model = Unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5)]
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)
gc.collect()
# Out:
# 0

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 304, 304, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 304, 304, 16) 448         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 304, 304, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 304, 304, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 152, 152, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 152, 152, 16) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 152, 152, 32) 4640        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 152, 152, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 152, 152, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 76, 76, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 76, 76, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 76, 76, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 76, 76, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 76, 76, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 38, 38, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 38, 38, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 38, 38, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 38, 38, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 38, 38, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 19, 19, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 19, 19, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 19, 19, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 19, 19, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 19, 19, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 38, 38, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38, 38, 256)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 38, 38, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 38, 38, 128)  295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 38, 38, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 38, 38, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 76, 76, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 76, 76, 128)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 76, 76, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 76, 76, 64)   73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 76, 76, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 76, 76, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 152, 152, 32) 18464       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 152, 152, 64) 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 152, 152, 64) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 152, 152, 32) 18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 152, 152, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 152, 152, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 304, 304, 16) 4624        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 304, 304, 32) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 304, 304, 32) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 304, 304, 16) 4624        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 304, 304, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 304, 304, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 304, 304, 1)  17          activation_17[0][0]
# ==================================================================================================
# Total params: 1,179,409
# Trainable params: 1,177,937
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-Unet.h5', verbose=1, save_best_only=True, save_weights_only=True),
    CSVLogger("dataResUnet.csv"),
    TensorBoard(log_dir='./logs')
]

# %%
results = model.fit(X_train, y_train, batch_size=6, epochs=5, callbacks=callbacks, validation_data=(X_test, y_test), use_multiprocessing=True)
# Out:
# Epoch 1/5
# 9/9 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.9639 - auc: 0.6341 - sensitivity_at_specificity: 0.6587 - specificity_at_sensitivity: 0.6472
# Epoch 00001: val_loss improved from inf to 10.70200, saving model to model-Unet.h5
# 9/9 [==============================] - 2s 187ms/step - loss: 0.2727 - accuracy: 0.9639 - auc: 0.6341 - sensitivity_at_specificity: 0.6587 - specificity_at_sensitivity: 0.6472 - val_loss: 10.7020 - val_accuracy: 0.1980 - val_auc: 0.2328 - val_sensitivity_at_specificity: 0.0000e+00 - val_specificity_at_sensitivity: 0.1485
# Epoch 2/5
# 9/9 [==============================] - ETA: 0s - loss: 0.2528 - accuracy: 0.9646 - auc: 0.6675 - sensitivity_at_specificity: 0.7592 - specificity_at_sensitivity: 0.6699
# Epoch 00002: val_loss improved from 10.70200 to 1.20785, saving model to model-Unet.h5
# 9/9 [==============================] - 2s 170ms/step - loss: 0.2528 - accuracy: 0.9646 - auc: 0.6675 - sensitivity_at_specificity: 0.7592 - specificity_at_sensitivity: 0.6699 - val_loss: 1.2079 - val_accuracy: 0.6423 - val_auc: 0.3457 - val_sensitivity_at_specificity: 0.3168 - val_specificity_at_sensitivity: 0.3788
# Epoch 3/5
# 9/9 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9648 - auc: 0.6888 - sensitivity_at_specificity: 0.7375 - specificity_at_sensitivity: 0.7246
# Epoch 00003: val_loss improved from 1.20785 to 0.83153, saving model to model-Unet.h5
# 9/9 [==============================] - 2s 170ms/step - loss: 0.2355 - accuracy: 0.9648 - auc: 0.6888 - sensitivity_at_specificity: 0.7375 - specificity_at_sensitivity: 0.7246 - val_loss: 0.8315 - val_accuracy: 0.7216 - val_auc: 0.3514 - val_sensitivity_at_specificity: 0.2623 - val_specificity_at_sensitivity: 0.3782
# Epoch 4/5
# 9/9 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.9651 - auc: 0.7311 - sensitivity_at_specificity: 0.8251 - specificity_at_sensitivity: 0.7547
# Epoch 00004: val_loss improved from 0.83153 to 0.26100, saving model to model-Unet.h5
# 9/9 [==============================] - 2s 169ms/step - loss: 0.2199 - accuracy: 0.9651 - auc: 0.7311 - sensitivity_at_specificity: 0.8251 - specificity_at_sensitivity: 0.7547 - val_loss: 0.2610 - val_accuracy: 0.9535 - val_auc: 0.5745 - val_sensitivity_at_specificity: 0.6591 - val_specificity_at_sensitivity: 0.5861
# Epoch 5/5
# 9/9 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9651 - auc: 0.7131 - sensitivity_at_specificity: 0.7902 - specificity_at_sensitivity: 0.7719
# Epoch 00005: val_loss did not improve from 0.26100
# 9/9 [==============================] - 1s 163ms/step - loss: 0.2079 - accuracy: 0.9651 - auc: 0.7131 - sensitivity_at_specificity: 0.7902 - specificity_at_sensitivity: 0.7719 - val_loss: 0.9587 - val_accuracy: 0.6545 - val_auc: 0.4991 - val_sensitivity_at_specificity: 0.5005 - val_specificity_at_sensitivity: 0.5031

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#        loss  accuracy  ...  val_specificity_at_sensitivity     lr
# 3  0.219856  0.965098  ...                        0.586061  0.001
# 2  0.235471  0.964778  ...                        0.378238  0.001
# 4  0.207915  0.965072  ...                        0.503120  0.001
# 1  0.252751  0.964639  ...                        0.378837  0.001
# 0  0.272715  0.963881  ...                        0.148538  0.001
#
# [5 rows x 11 columns]

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %% [markdown]
# # **Inference**

# %%
model.load_weights('model-Unet.h5')

# %%
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.9535 - auc: 0.5745 - sensitivity_at_specificity: 0.6591 - specificity_at_sensitivity: 0.5861
# [0.2610020637512207,
#  0.9535083770751953,
#  0.5744533538818359,
#  0.6591055393218994,
#  0.5860614776611328]

# %%
# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_test, verbose=1)
# Out:
# 2/2 [==============================] - 1s 317ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    """Function to plot the results"""
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Satellight Image')
    ax[0].set_axis_off()

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Satellight Mask Image')
    ax[1].set_axis_off()

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Satelight Image Predicted')
    ax[2].set_axis_off()
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Satellight Mask Image Predicted binary');
    ax[3].set_axis_off()

# %% [markdown]
# # **Predictions on training set**

# %%
# Check if training data looks all right
plot_sample(X_train, y_train, preds_train, preds_train_t, ix=14)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)
